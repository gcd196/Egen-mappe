# %% [markdown]
# # An examination of the relative price in the Koopman model

# %% [markdown]
# In this project we want to examine the relative price set in the Koopman model. We want to see how the price depends on the parameters of the model. In doing so we take two approaches: First, we derive an analytical solution and plot the results in an interattive figure, second, we try to solve the by solving the model numerically. Specifically we use a bisection method. The baseline model assumes that the consumer has a Cobb-Douglas utility function. We extend the model by assuming a CES-utility function.

# %% [markdown]
# Imports and set magics:

# %%
import numpy as np
from scipy import optimize
import sympy as sm
import ipywidgets as widgets # Interactive plots
import matplotlib.pyplot as plt

# autoreload modules when code is run
# %load_ext autoreload
# %autoreload 2

# local modules
import analytical_solution as ana
import numerical_solution as num
import CES_function as ces

# %% [markdown]
# # 1. Model description of baseline model

# %% [markdown]
# **Time:** One period.

# %% [markdown]
# **Demographics:** Initially one consumer and one firm. The firm is owned by the consumer and therefore the income also depends on the profit. We do not assume initial goods endowments.

# %% [markdown]
# **Household:** For our baseline model we assume that the consumer has Cobb-Douglas preferences, where the two goods are the product (c) and leisure (l)
# $$
# \begin{aligned}
# & \max \ u =c^{\alpha}*l^{1-\alpha}, 0<\alpha<1\\
#  & \text{s.t.}\\
#  & I=\Pi + w*L=p*c +w*l \\
#
# \end{aligned}
# $$
#
# ${\alpha}$ is the relative preference towards consumption, p is the price of the good, w is the wage, L is the initial labor endowment, l is leisure and $\Pi$ is the profit. We have assumed monotonicity. Further, we have the firm problem:
# $$
# \begin{aligned}
# &\Pi =p*y-w*h
#
# \end{aligned}
# $$
#
# The production function will be defined as follow, where the interpretation of A can be TFP, and ${\beta}$ determines the returns to scale:
#
# $$
# \begin{aligned}
# &y =A*h^{\beta}, \beta <1 \\
# &\max \ \Pi =p*A*h^{\beta}-w*h
#
# \end{aligned}
# $$
#
# We assume the initial labor endowment is 24 hours, i.e. a day. We can therefore define the following relationsship in equilibrium:
# $$
# \begin{aligned}
# &L=24=l+h
#
# \end{aligned}
# $$

# %% [markdown]
# **Equilibrium:** The procedure is defined where the labor market (l+h=24) and good market (y=c) clear. Further, the firm has maximized its profit and the consumer has maximized its utility.

# %% [markdown]
# ## 2. Analytical solution

# %% [markdown]
# The baseline model can be solved analytically. The starting point is to derive the firm's demand for labor. This is done by taking the FOC of the profit function w.r.t. working hours. This leads to the following result:
#
# $$
# \begin{aligned}
# & h^*=(\frac{\beta*p*A}{w})^{\frac{1}{1-\beta}}
# \end{aligned}
# $$

# %% [markdown]
# And from this the solutions for the firm's output and profit follow easily:
#
# $$
# \begin{aligned}
# & y^*=A*(\frac{\beta*p*A}{w})^{\frac{\beta}{1-\beta}}\\
# & \Pi^*=p*A*(\frac{\beta*p*A}{w})^{\frac{\beta}{1-\beta}}-w(\frac{\beta*p*A}{w})^{\frac{1}{1-\beta}}
# \end{aligned}
# $$

# %% [markdown]
# Now, we will solve for the consumer's problem. It should be noted that the working hours and profit is exogenous for the consumer as the firm has already decided this based on the prices. As we have assumed a Cobb-Douglas function, we can use the standard solution shown below:
#
# $$
# \begin{aligned}
# & c^*=\alpha*\frac {I}{p}\\
# & l^*=(1-\alpha)*\frac{I}{w}
# \end{aligned}
# $$
#
# Where the income is:
#
# $$
# \begin{aligned}
# & I= \Pi+L = p*A*(\frac{\beta*p*A}{w})^{\frac{\beta}{1-\beta}}-w(\frac{\beta*p*A}{w})^{\frac{1}{1-\beta}} + L
# \end{aligned}
# $$

# %% [markdown]
# Now we want to find the prices in equilibrium, that is, where the goods market and the labor market clears. We set the wage as numeraire, i.e. w=1, and then find the relative price p. We can then solve for the labor market:
#
# $$
# \begin{aligned}
# & l^*=L-h^*\\
# & \leftrightarrow (1-\alpha)*(p*A*(\beta*p*A)^{\frac{\beta}{1-\beta}}-(\beta*p*A)^{\frac{1}{1-\beta}}+L)=L-(\beta*p*A)^{\frac{1}{1-\beta}}
# \end{aligned}
# $$
#
# Solving this for p gives:
#
# $$
# \begin{aligned}
# & p^*=\frac {L^{1-\beta}}{A}*\frac {1}{(\beta^\frac {\beta}{1-\beta}*(1-\alpha)+\alpha*\beta^\frac {1}{1-\beta})^{1-\beta}}
# \end{aligned}
# $$
#
# We see that higher productivity (A) decreases the price, which makes intuively sense as this will increase the supply. Further, higher demand ($\alpha$) will increase the price, which again makes intuitively sense. With this price we have the general solution, which can be plotted below.

# %% [markdown]
# Note, given Walras' law, we know that this relative price also solves the goods market.

# %% [markdown]
# Now we have the general solution. This can be illustrated by using specific values for the parameters in the model. In the figure below we plot alpha on the x-axis and price on the y-axis, and then we add sliders for the values of $\beta$ and A.

# %%
#Interactive figure with beta and A as sliders
widgets.interact(ana.interactive_figure,
    beta=widgets.FloatSlider(description=r"beta", min=0., max=0.99, step=0.10, value=0.5), 
    A=widgets.FloatSlider(description=r"A", min=1, max=10, step=1, value=5),
);
# Out:
# interactive(children=(FloatSlider(value=0.5, description='beta', max=0.99), FloatSlider(value=5.0, description…

# %% [markdown]
# What we see from the graph directly follows from the points made above. Further, we see a decreasing relationship with $\beta$, when adjusting the slider for this parameter. This relationship also makes sense given that $\beta$ determines how much returns to scale are decreasing: A higher value of $\beta$ means higher returns to scale and from this follows a higher supply.

# %% [markdown]
# ## Numerical solution

# %% [markdown]
# In this section we solve the model numerically using the bisection method. We use the bisection method, because we know that when the goods market clears, then excess supply should be equal 0. We can use this to find the price that equilibriates supply and demand of the good: If excess supply is positive, then we know that the price is too high, and oppositely if excess supply is negative, then we know that the price is too low.

# %% [markdown]
# **Problem:** Given a list of positive numbers, return the relative price that solves the goods market (and the labor market given Walras' Law).
#
# **Inputs:** A range of possible solutions, and values of alpha, beta, A and L respectively.
#
# **Outputs:** Relative price $p$.
#
# **Algorithm:** `numerical_solution()`
#
# 1. For a given $p$, $\beta$, and $\alpha$ determine excess supply on the goods market and excess demand on the labor market following utility and profit maximization.
# 2. Set tolerance level $\epsilon$, maximum number of iterations, and lower and upper bounds for possible solutions: $p_{lower}$ and $p_{upper}$.
# *  Note, the relative price cannot be negative.
# 3. Compute the excess supply for both the upper and lower bound: $ES(p_{lower})$ and $ES(p_{upper})$
# 4. Compute midpoint: $p_{mid}=\frac{p_{lower}+p_{upper}}{2}$
# 5. Compute excess supply for the midpoint: $ES(p_{mid})$
# 6. Update the interval:
#   * If $ES(p_{lower})*ES(p_{mid})<0$ then update so $p_{upper}=p_{mid}$
#   * If $ES(p_{mid})*ES(p_{upper})<0$ then update so $p_{lower}=p_{mid}$
# 7. Repeat step 3-6 until $ES(p_{mid})<\epsilon$

# %% [markdown]
# To again examine how the market clearing relative price changes for values of $\alpha$ and $\beta$ we now loop over ranges of values for these two parameters.

# %%
#call class
sol=num.NumericalSolution()

# %%
#Alpha

# a. determine size of vectors
N=10

# b. create empty vectors
alpha_vec_num=np.empty(N)
p_vec_num_alpha=np.empty(N)
c_clearing_alpha=np.empty(N)
l_clearing_alpha=np.empty(N)

# c. loop over the specified amount of alpha values and solve the model numerically each tim
for i, alpha in enumerate(np.linspace(start=0.01, stop = 0.99, num=N)):
    # Call find_relative_price with current alpha value
    alpha_baseline=sol.par.alpha
    sol.par.alpha=alpha
    alpha_vec_num[i]=alpha
    p_vec_num_alpha[i],c_clearing_alpha[i], l_clearing_alpha[i] = sol.find_relative_price(tol=1e-4, p_lower=0, p_upper=1000)
    sol.par.alpha=alpha_baseline
# Out:
# c:\Users\Ander\OneDrive - University of Copenhagen\Kandidat\1. semester\Introduction to Programming and Numerical Analysis\Python\Egen-mappe\modelproject\numerical_solution.py:100: RuntimeWarning: divide by zero encountered in double_scalars
#   sol.c_star = par.alpha*utility_inc/p
#  Step 28.00: p = 0.06 -> Good clearing = -0.00008745. Labor clearing = -0.00.
#  Step 29.00: p = 0.22 -> Good clearing = 0.00008209. Labor clearing = 0.00.
#  Step 30.00: p = 0.31 -> Good clearing = 0.00000735. Labor clearing = 0.00.
#  Step 30.00: p = 0.39 -> Good clearing = 0.00001447. Labor clearing = 0.00.
#  Step 30.00: p = 0.46 -> Good clearing = 0.00001993. Labor clearing = 0.00.
#  Step 28.00: p = 0.54 -> Good clearing = -0.00006501. Labor clearing = -0.00.
#  Step 28.00: p = 0.61 -> Good clearing = -0.00003563. Labor clearing = -0.00.
#  Step 28.00: p = 0.69 -> Good clearing = 0.00000167. Labor clearing = 0.00.
#  Step 27.00: p = 0.77 -> Good clearing = -0.00002467. Labor clearing = -0.00.
#  Step 46.00: p = 0.86 -> Good clearing = -0.00003263. Labor clearing = -0.00.

# %%
#Beta

beta_vec_num=np.empty(N)
p_vec_num_beta=np.empty(N)
c_clearing_beta=np.empty(N)
l_clearing_beta=np.empty(N)

for i, beta in enumerate(np.linspace(start=0.01, stop = 0.8, num=N)):
    # Call find_relative_price with current beta value
    beta_baseline=sol.par.beta
    sol.par.beta=beta
    beta_vec_num[i]=beta
    p_vec_num_beta[i],c_clearing_beta[i], l_clearing_beta[i] = sol.find_relative_price(tol=1e-4, p_lower=0, p_upper=1000, iterations=500)
    sol.par.beta=beta_baseline
# Out:
#  Step 23.00: p = 3.72 -> Good clearing = -0.00005202. Labor clearing = -0.00.
#  Step 22.00: p = 2.84 -> Good clearing = -0.00007786. Labor clearing = -0.00.
#  Step 24.00: p = 2.00 -> Good clearing = 0.00004528. Labor clearing = 0.00.
#  Step 26.00: p = 1.38 -> Good clearing = -0.00005531. Labor clearing = -0.00.
#  Step 28.00: p = 0.94 -> Good clearing = 0.00005836. Labor clearing = 0.00.
#  Step 26.00: p = 0.63 -> Good clearing = -0.00003959. Labor clearing = -0.00.
#  Step 30.00: p = 0.42 -> Good clearing = 0.00009056. Labor clearing = 0.00.
#  Step 31.00: p = 0.28 -> Good clearing = 0.00007179. Labor clearing = 0.00.
#  Step 31.00: p = 0.19 -> Good clearing = -0.00002693. Labor clearing = -0.00.
#  Step 47.00: p = 0.13 -> Good clearing = 0.00002834. Labor clearing = 0.00.

# %% [markdown]
# And present them in two separate figures:

# %%
# a. figure with alpha on x-axis
fig = plt.figure(figsize=(8,10))
dx = fig.add_subplot(2,1,1)
dx.plot(alpha_vec_num, p_vec_num_alpha, label='Price of consumption relative to leisure')
dx.set_xlim([0.0,1]) # 
dx.set_ylim([0,1]) #
dx.set_title("Price")
dx.set_xlabel("Alpha") 
dx.legend(loc= 'upper right')

# b. figure with beta on x-axis
dx = fig.add_subplot(2,1,2)
dx.plot(beta_vec_num, p_vec_num_beta, label='Price of consumption relative to leisure')
dx.set_xlim([0.0,0.85]) # 
dx.set_ylim([0,4]) #
dx.set_title("Price")
dx.set_xlabel("Beta") 
dx.legend(loc= 'upper right')

plt.show()

# %% [markdown]
# From the graphs we see the same relationship as also uncovered under the analytical solution. See that section for interpretation.

# %% [markdown]
# # Further analysis

# %% [markdown]
# In this section we will change the utility function for the consumer. The reason for this is that with a Cobb-Douglas function we make som strong assumptions about the degree of substitutability. To be specific, we assume that the income effect is equal to the substitution effect with Cobb-Douglas. However, it could easily be stated that the leisure and consumption is closer to be perfect complements (low value of $\sigma$), because you cannot enjoy leisure without consumption, and consumption without time to consume is also not that valuable. We will also see how an assumption about leisure and consumption is more like perfect substitutes (high value of $\sigma$) will affect the price change for a change in $\beta$. Our new utility function is:
#
# $$
# \begin{aligned}
# & u =(c^{\frac {\sigma-1}{\sigma}}+l^{\frac {\sigma-1}{\sigma}})^{\frac {\sigma}{\sigma-1}}, 0<\sigma<\infty \\
#  & \text{s.t.}\\
#  & I=\Pi + w*L=p*c +w*l \\
# \end{aligned}
# $$
#
# It should be noted we set the initial labor endowment equal to 75 in order to strength the tendency in the optimization problem. It is only  to stress out the effect of changes in $\beta$

# %%
#call ces-class
ces=ces.NumericalSolutionCES()

# %%
#

#a. Specify list of values of sigma to be considered
sigma_values=[0.10,0.5,5,50]

#b. Create empty vectors to be filled
beta_vec_num = np.empty((3,))
sigma_vec_num = np.empty((4,))
p_vec_num_beta_ces=np.empty((3,4))
c_clearing_beta_ces=np.empty((3,4))
l_clearing_beta_ces=np.empty((3,4))

#c. initiate plot
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

#d. solve model using for different values of beta and sigma + plot relationship
for j, sigma in enumerate(sigma_values):
    sigma_baseline=ces.par.sigma
    ces.par.sigma=sigma
    sigma_vec_num[j] = sigma
    for i, beta in enumerate(np.linspace(start=0.2, stop = 0.7, num=3)):
        # Call find_relative_price with current alpha value
        beta_baseline=ces.par.beta
        ces.par.beta=beta
        beta_vec_num[i]=beta
        p_vec_num_beta_ces[i,j], c_clearing_beta_ces[i,j], l_clearing_beta_ces[i,j] = ces.find_relative_price(tol=1e-4, p_lower=0, p_upper=1000)
        ces.par.beta=beta_baseline
    ces.par.sigma=sigma_baseline
    ax.plot(beta_vec_num,p_vec_num_beta_ces[:,j],label=f'$Sigma = {sigma}$')

#e. Specify layout of plot
ax.legend(loc='lower right',facecolor='white',frameon=True)
ax.set_xlabel('$beta$')
ax.set_ylabel('$price$')
ax.set_title('The relationship between price, sigma and beta')
ax.set_xlim([0,1])
ax.set_ylim([0,5])
# Out:
#  Step 22.00: Beta = 0.20. Sigma = 0.10  p = 3.79 -> Good clearing = -0.00. Labor clearing = -0.00. Consumption = 39.46
#  Step 25.00: Beta = 0.45. Sigma = 0.10  p = 0.48 -> Good clearing = -0.00. Labor clearing = -0.00. Consumption = 65.67
#  Step 32.00: Beta = 0.70. Sigma = 0.10  p = 0.13 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 82.60
#  Step 22.00: Beta = 0.20. Sigma = 0.50  p = 2.54 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 35.70
#  Step 29.00: Beta = 0.45. Sigma = 0.50  p = 0.56 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 75.04
#  Step 32.00: Beta = 0.70. Sigma = 0.50  p = 0.17 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 143.20
#  Step 28.00: Beta = 0.20. Sigma = 5.00  p = 1.18 -> Good clearing = -0.00. Labor clearing = -0.00. Consumption = 29.49
#  Step 29.00: Beta = 0.45. Sigma = 5.00  p = 0.82 -> Good clearing = -0.00. Labor clearing = -0.00. Consumption = 102.36
#  Step 32.00: Beta = 0.70. Sigma = 5.00  p = 0.26 -> Good clearing = -0.00. Labor clearing = -0.00. Consumption = 408.87
#  Step 30.00: Beta = 0.20. Sigma = 50.00  p = 1.02 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 28.41
#  Step 31.00: Beta = 0.45. Sigma = 50.00  p = 0.97 -> Good clearing = -0.00. Labor clearing = -0.00. Consumption = 117.60
#  Step 10.00: Beta = 0.70. Sigma = 50.00  p = 0.49 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 410.75
# (0.0, 5.0)

# %% [markdown]
# The results see from the figure above is in line with our expectations. Let's consider a decrease a $\beta$. This will give a lower supply in this model. Ceteris paribus this will give a lower price, but the elasticity of substitution will have an influence on the quantivately change. For $\sigma$ close to 0, we have almost perfect complements. Therefore, if the supply of goods decrease, the consumer will have to pay more for the good in order to keep a balance between leisure and consumption. This will lead to a big price decreases, i.e. the blue curve. The opposite will be true for a high degree of substitutability, which is also what we can see from the red curve above.

# %% [markdown]
# # Conclusion

# %% [markdown]
# In the baseline model we find a positive relationship between $\alpha$ and the price. This is because a higher $\alpha$ will increase the demand and hereby the price. On the other hand, we find a negative relationship between $\beta$ and the price, as a higher $\beta$ will increase supply and hereby the price.
#
# In our extended model we find that a higher degree of substitutability will lead to a lower effect on the price when $\beta$ (supply) is changing. This can be explained by the fact that if the supply goes down and consumption and leisure are close to be perfect complements, the consumer will need the consumption relatively more and therefore the price increase will be higher.

# %%
import cProfile
import pstats

def run_code():
    # The rest of your code goes here
    
    #a. Specify list of values of sigma to be considered
    sigma_values=[0.10,0.5,5,50]

    #b. Create empty vectors to be filled
    beta_vec_num = np.empty((3,))
    sigma_vec_num = np.empty((4,))
    p_vec_num_beta_ces=np.empty((3,4))
    c_clearing_beta_ces=np.empty((3,4))
    l_clearing_beta_ces=np.empty((3,4))

    #c. initiate plot
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)

    #d. solve model using for different values of beta and sigma + plot relationship
    for j, sigma in enumerate(sigma_values):
        sigma_baseline=ces.par.sigma
        ces.par.sigma=sigma
        sigma_vec_num[j] = sigma
        for i, beta in enumerate(np.linspace(start=0.2, stop = 0.7, num=3)):
            # Call find_relative_price with current alpha value
            beta_baseline=ces.par.beta
            ces.par.beta=beta
            beta_vec_num[i]=beta
            p_vec_num_beta_ces[i,j], c_clearing_beta_ces[i,j], l_clearing_beta_ces[i,j] = ces.find_relative_price(tol=1e-4, p_lower=0.5, p_upper=1.5)
            ces.par.beta=beta_baseline
        ces.par.sigma=sigma_baseline
        ax.plot(beta_vec_num,p_vec_num_beta_ces[:,j],label=f'$Sigma = {sigma}$')

    #e. Specify layout of plot
    ax.legend(loc='lower right',facecolor='white',frameon=True)
    ax.set_xlabel('$beta$')
    ax.set_ylabel('$price$')
    ax.set_title('The relationship between price, sigma and beta')
    ax.set_xlim([0,1])
    ax.set_ylim([0,5])

# Create a profiler
profiler = cProfile.Profile()

# Run the code inside the profiler
profiler.runcall(run_code)

# Create a Stats object to format and print the profile data
stats = pstats.Stats(profiler)

# Sort the data by the cumulative time spent in the functions
stats.sort_stats('cumulative')

# Print the profile data
stats.print_stats()
# Out:
# Fail
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 48
#      45 profiler = cProfile.Profile()
#      47 # Run the code inside the profiler
# ---> 48 profiler.runcall(run_code)
#      50 # Create a Stats object to format and print the profile data
#      51 stats = pstats.Stats(profiler)
#
# File c:\Users\Ander\anaconda3\lib\cProfile.py:109, in Profile.runcall(self, func, *args, **kw)
#     107 self.enable()
#     108 try:
# --> 109     return func(*args, **kw)
#     110 finally:
#     111     self.disable()
#
# Cell In[13], line 31, in run_code()
#      29     ces.par.beta=beta
#      30     beta_vec_num[i]=beta
# ---> 31     p_vec_num_beta_ces[i,j], c_clearing_beta_ces[i,j], l_clearing_beta_ces[i,j] = ces.find_relative_price(tol=1e-4, p_lower=0.5, p_upper=1.5)
#      32     ces.par.beta=beta_baseline
#      33 ces.par.sigma=sigma_baseline
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
def run_code():
    # The rest of your code goes here
    
    #a. Specify list of values of sigma to be considered
    sigma_values=[0.10,0.5,5,50]

    #b. Create empty vectors to be filled
    beta_vec_num = np.empty((3,))
    sigma_vec_num = np.empty((4,))
    p_vec_num_beta_ces=np.empty((3,4))
    c_clearing_beta_ces=np.empty((3,4))
    l_clearing_beta_ces=np.empty((3,4))

    #c. initiate plot
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)

    #d. solve model using for different values of beta and sigma + plot relationship
    for j, sigma in enumerate(sigma_values):
        sigma_baseline=ces.par.sigma
        ces.par.sigma=sigma
        sigma_vec_num[j] = sigma
        for i, beta in enumerate(np.linspace(start=0.2, stop = 0.7, num=3)):
            # Call find_relative_price with current alpha value
            beta_baseline=ces.par.beta
            ces.par.beta=beta
            beta_vec_num[i]=beta
            p_vec_num_beta_ces[i,j], c_clearing_beta_ces[i,j], l_clearing_beta_ces[i,j] = ces.find_relative_price_new(p_lower=0, p_upper=1000)
            ces.par.beta=beta_baseline
        ces.par.sigma=sigma_baseline
        ax.plot(beta_vec_num,p_vec_num_beta_ces[:,j],label=f'$Sigma = {sigma}$')

    #e. Specify layout of plot
    ax.legend(loc='lower right',facecolor='white',frameon=True)
    ax.set_xlabel('$beta$')
    ax.set_ylabel('$price$')
    ax.set_title('The relationship between price, sigma and beta')
    ax.set_xlim([0,1])
    ax.set_ylim([0,5])

# Create a profiler
profiler = cProfile.Profile()

# Run the code inside the profiler
profiler.runcall(run_code)

# Create a Stats object to format and print the profile data
stats = pstats.Stats(profiler)

# Sort the data by the cumulative time spent in the functions
stats.sort_stats('cumulative')

# Print the profile data
stats.print_stats()
# Out:
#  Beta = 0.20. Sigma = 0.10  p = 3.79 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 39.46
#  Beta = 0.45. Sigma = 0.10  p = 0.48 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 65.67
#  Beta = 0.70. Sigma = 0.10  p = 0.13 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 82.60
#  Beta = 0.20. Sigma = 0.50  p = 2.54 -> Good clearing = -0.00. Labor clearing = -0.00. Consumption = 35.70
#  Beta = 0.45. Sigma = 0.50  p = 0.56 -> Good clearing = -0.00. Labor clearing = -0.00. Consumption = 75.04
#  Beta = 0.70. Sigma = 0.50  p = 0.17 -> Good clearing = -0.00. Labor clearing = -0.00. Consumption = 143.20
#  Beta = 0.20. Sigma = 5.00  p = 1.18 -> Good clearing = -0.00. Labor clearing = -0.00. Consumption = 29.49
#  Beta = 0.45. Sigma = 5.00  p = 0.82 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 102.36
#  Beta = 0.70. Sigma = 5.00  p = 0.26 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 408.87
#  Beta = 0.20. Sigma = 50.00  p = 1.02 -> Good clearing = -0.00. Labor clearing = -0.00. Consumption = 28.41
#  Beta = 0.45. Sigma = 50.00  p = 0.97 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 117.60
#  Beta = 0.70. Sigma = 50.00  p = 0.49 -> Good clearing = 0.00. Labor clearing = 0.00. Consumption = 410.75
#          99800572 function calls (97080095 primitive calls) in 142.885 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000  142.885  142.885 C:\Users\Ander\AppData\Local\Temp\ipykernel_3584\2788266792.py:1(run_code)
#        12    0.000    0.000  142.827   11.902 c:\Users\Ander\OneDrive - University of Copenhagen\Kandidat\1. semester\Introduction to Programming and Numerical Analysis\Python\Egen-mappe\modelproject\CES_function.py:207(find_relative_price_new)
# 24002/844    0.510    0.000  142.810    0.169 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_minimize.py:45(minimize)
#       428    0.005    0.000  140.164    0.327 c:\Users\Ander\OneDrive - University of Copenhagen\Kandidat\1. semester\Introduction to Programming and Numerical Analysis\Python\Egen-mappe\modelproject\CES_function.py:103(maximize_utility)
#       428    0.321    0.001  140.079    0.327 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_slsqp_py.py:214(_minimize_slsqp)
#     23574    0.203    0.000  139.459    0.006 c:\Users\Ander\OneDrive - University of Copenhagen\Kandidat\1. semester\Introduction to Programming and Numerical Analysis\Python\Egen-mappe\modelproject\CES_function.py:53(firm_profit_maximization)
#       416    0.003    0.000  138.585    0.333 c:\Users\Ander\OneDrive - University of Copenhagen\Kandidat\1. semester\Introduction to Programming and Numerical Analysis\Python\Egen-mappe\modelproject\CES_function.py:134(market_clearing)
#     23158    0.098    0.000  136.900    0.006 c:\Users\Ander\OneDrive - University of Copenhagen\Kandidat\1. semester\Introduction to Programming and Numerical Analysis\Python\Egen-mappe\modelproject\CES_function.py:92(ineq_constraint)
#     23574    7.573    0.000  135.824    0.006 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_lbfgsb_py.py:210(_minimize_lbfgsb)
#        12    0.000    0.000  129.914   10.826 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_root_scalar.py:61(root_scalar)
#        12    0.000    0.000  129.914   10.826 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_zeros_py.py:658(brentq)
#        12    0.001    0.000  129.914   10.826 {built-in method scipy.optimize._zeros._brentq}
#       392    0.001    0.000  129.913    0.331 c:\Users\Ander\OneDrive - University of Copenhagen\Kandidat\1. semester\Introduction to Programming and Numerical Analysis\Python\Egen-mappe\modelproject\CES_function.py:214(function_to_solve)
# 681662/212141   18.503    0.000  128.609    0.001 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py:275(approx_derivative)
#    670630    1.496    0.000  119.331    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:282(fun_and_grad)
# 698210/228689    1.174    0.000  103.621    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py:455(fun_wrapped)
#    700148    0.475    0.000  100.495    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:254(_update_grad)
#    676146    2.069    0.000  100.020    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:170(update_grad)
#      5516    0.040    0.000   99.033    0.018 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_slsqp_py.py:483(_eval_con_normals)
#      5516    0.016    0.000   98.800    0.018 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_slsqp_py.py:492(<listcomp>)
#      5516    0.026    0.000   98.784    0.018 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_slsqp_py.py:293(cjac)
# 681662/368648    6.981    0.000   82.787    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py:566(_dense_difference)
# 10755094/9310624    9.684    0.000   42.439    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      6182    0.032    0.000   36.397    0.006 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_slsqp_py.py:464(_eval_constraint)
#      6182    0.018    0.000   36.310    0.006 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_slsqp_py.py:473(<listcomp>)
#    681662   20.344    0.000   31.327    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py:11(_adjust_scheme_to_bounds)
#   1358460    4.500    0.000   25.996    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:132(fun_wrapped)
#   1376960    0.553    0.000   13.497    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:249(_update_fun)
#   1341260    4.650    0.000   13.401    0.000 c:\Users\Ander\OneDrive - University of Copenhagen\Kandidat\1. semester\Introduction to Programming and Numerical Analysis\Python\Egen-mappe\modelproject\CES_function.py:43(firm_profit)
#    676798    0.443    0.000   12.944    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:154(update_fun)
#   2835434    1.713    0.000   11.319    0.000 <__array_function__ internals>:177(atleast_1d)
#   1364834    8.787    0.000    8.787    0.000 c:\Users\Ander\OneDrive - University of Copenhagen\Kandidat\1. semester\Introduction to Programming and Numerical Analysis\Python\Egen-mappe\modelproject\CES_function.py:27(production_function)
#   2835434    3.902    0.000    7.785    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\shape_base.py:23(atleast_1d)
#   1410933    2.564    0.000    7.362    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:69(_wrapreduction)
#    705260    0.555    0.000    6.564    0.000 <__array_function__ internals>:177(any)
#   2176127    6.243    0.000    6.243    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    682328    0.487    0.000    6.104    0.000 <__array_function__ internals>:177(array_equal)
#    681662    0.675    0.000    5.548    0.000 <__array_function__ internals>:177(ones_like)
#     24002    0.174    0.000    5.393    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_optimize.py:244(_prepare_scalar_function)
#     24002    0.362    0.000    5.215    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:86(__init__)
#    682328    1.926    0.000    5.137    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\numeric.py:2388(array_equal)
#    705673    0.493    0.000    5.063    0.000 <__array_function__ internals>:177(all)
#    705260    0.815    0.000    4.832    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2305(any)
#    681662    0.508    0.000    4.379    0.000 <__array_function__ internals>:177(diag)
#    681662    0.996    0.000    4.361    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\numeric.py:218(ones_like)
#    705673    0.726    0.000    4.071    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2404(all)
#   1358482    1.610    0.000    3.975    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\numeric.py:1859(isscalar)
#   1382462    0.881    0.000    3.616    0.000 <__array_function__ internals>:177(copy)
#    652796    0.995    0.000    3.447    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:240(update_x)
#    681662    2.600    0.000    3.331    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\twodim_base.py:234(diag)
#    682329    0.437    0.000    3.007    0.000 {method 'all' of 'numpy.ndarray' objects}
#       428    0.001    0.000    2.826    0.007 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_slsqp_py.py:329(<listcomp>)
#    681662    0.509    0.000    2.620    0.000 <__array_function__ internals>:177(where)
#    682329    0.307    0.000    2.570    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\_methods.py:60(_all)
#   3716800    1.325    0.000    2.557    0.000 {built-in method builtins.isinstance}
#   1476148    2.281    0.000    2.281    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#    687178    0.500    0.000    2.245    0.000 <__array_function__ internals>:177(ravel)
#     48004    0.116    0.000    2.086    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_minimize.py:961(standardize_bounds)
#   1382462    0.496    0.000    1.866    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\function_base.py:846(copy)
#    681666    0.520    0.000    1.686    0.000 <__array_function__ internals>:177(copyto)
#    681666    0.548    0.000    1.679    0.000 <__array_function__ internals>:177(empty_like)
#    681662    0.769    0.000    1.616    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py:193(_prepare_bounds)
#   1656855    1.524    0.000    1.524    0.000 {built-in method numpy.array}
#   1382480    1.373    0.000    1.373    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     11698    0.020    0.000    1.269    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_optimize.py:344(eval)
#    687178    0.744    0.000    1.268    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:1755(ravel)
#   1341511    0.414    0.000    1.232    0.000 c:\Users\Ander\anaconda3\lib\abc.py:117(__instancecheck__)
#     23574    0.238    0.000    1.212    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_lbfgsb_py.py:427(__init__)
#   4250400    1.140    0.000    1.140    0.000 {built-in method numpy.asanyarray}
#     24002    0.105    0.000    0.946    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_constraints.py:389(new_bounds_to_old)
#      5516    0.012    0.000    0.935    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:270(grad)
#    681662    0.553    0.000    0.848    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py:204(<listcomp>)
#   1341511    0.818    0.000    0.818    0.000 {built-in method _abc._abc_instancecheck}
#   4918473    0.815    0.000    0.815    0.000 {built-in method numpy.asarray}
#     24002    0.093    0.000    0.809    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_constraints.py:249(__init__)
#    959047    0.725    0.000    0.725    0.000 {built-in method numpy.zeros}
#   1410933    0.715    0.000    0.715    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:70(<dictcomp>)
#     48004    0.036    0.000    0.695    0.000 <__array_function__ internals>:177(broadcast_to)
#     24002    0.029    0.000    0.655    0.000 <__array_function__ internals>:177(clip)
#     48004    0.035    0.000    0.620    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:366(broadcast_to)
#     23574    0.078    0.000    0.611    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\sparse\linalg\_interface.py:157(__init__)
#     49288    0.426    0.000    0.601    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:339(_broadcast_to)
#     24002    0.036    0.000    0.601    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2083(clip)
#     24026    0.029    0.000    0.565    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:51(_wrapfunc)
#    681757    0.564    0.000    0.564    0.000 {method 'copy' of 'numpy.ndarray' objects}
#     23574    0.058    0.000    0.533    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\sparse\_sputils.py:238(isshape)
#     24002    0.027    0.000    0.527    0.000 {method 'clip' of 'numpy.ndarray' objects}
#     24002    0.104    0.000    0.499    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\_methods.py:125(_clip)
#   1513818    0.489    0.000    0.489    0.000 {method 'startswith' of 'bytes' objects}
#    142308    0.118    0.000    0.480    0.000 <__array_function__ internals>:177(ndim)
#     24002    0.052    0.000    0.441    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_constraints.py:241(_input_validation)
#    681667    0.433    0.000    0.433    0.000 {built-in method numpy.empty}
# 3601345/3601343    0.430    0.000    0.430    0.000 {built-in method builtins.len}
#   2876746    0.394    0.000    0.394    0.000 {method 'append' of 'list' objects}
#     24012    0.034    0.000    0.390    0.000 <__array_function__ internals>:177(broadcast_arrays)
#     48004    0.143    0.000    0.369    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_constraints.py:407(old_bound_to_new)
#   1104011    0.368    0.000    0.368    0.000 {method 'tobytes' of 'numpy.ndarray' objects}
#     23574    0.032    0.000    0.363    0.000 <__array_function__ internals>:177(einsum)
#     47148    0.081    0.000    0.338    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\sparse\_sputils.py:216(isintlike)
#     24012    0.094    0.000    0.326    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:479(broadcast_arrays)
#   2835434    0.322    0.000    0.322    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\shape_base.py:19(_atleast_1d_dispatcher)
#    710780    0.316    0.000    0.316    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#   1341260    0.315    0.000    0.315    0.000 {method 'item' of 'numpy.ndarray' objects}
#     82433    0.056    0.000    0.308    0.000 {method 'any' of 'numpy.ndarray' objects}
#   1413656    0.278    0.000    0.278    0.000 {method 'items' of 'dict' objects}
#     48004    0.178    0.000    0.275    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\_methods.py:91(_clip_dep_is_scalar_nan)
#    142308    0.215    0.000    0.267    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3164(ndim)
#     82441    0.042    0.000    0.252    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\_methods.py:54(_any)
#     23574    0.026    0.000    0.226    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\einsumfunc.py:997(einsum)
#     23574    0.200    0.000    0.200    0.000 {built-in method numpy.core._multiarray_umath.c_einsum}
#     17214    0.059    0.000    0.191    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_optimize.py:351(_check_clip_x)
#   1382462    0.190    0.000    0.190    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\function_base.py:842(_copy_dispatcher)
#      6182    0.020    0.000    0.180    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:264(fun)
#     11032    0.011    0.000    0.168    0.000 <__array_function__ internals>:177(vstack)
#     35034    0.029    0.000    0.150    0.000 <__array_function__ internals>:177(atleast_2d)
#     34456    0.031    0.000    0.137    0.000 <__array_function__ internals>:177(concatenate)
#    692958    0.131    0.000    0.131    0.000 {built-in method builtins.abs}
#    705260    0.127    0.000    0.127    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2300(_any_dispatcher)
#     11032    0.025    0.000    0.125    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\shape_base.py:222(vstack)
#    681662    0.112    0.000    0.112    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\multiarray.py:341(where)
#     24012    0.109    0.000    0.112    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:415(_broadcast_shape)
#     24002    0.111    0.000    0.111    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_constraints.py:401(<listcomp>)
#    682328    0.110    0.000    0.110    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\numeric.py:2384(_array_equal_dispatcher)
#    681662    0.105    0.000    0.105    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\twodim_base.py:230(_diag_dispatcher)
#    681662    0.102    0.000    0.102    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\numeric.py:214(_ones_like_dispatcher)
#    705673    0.101    0.000    0.101    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2399(_all_dispatcher)
#    687178    0.099    0.000    0.099    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:1751(_ravel_dispatcher)
#    681666    0.098    0.000    0.098    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\multiarray.py:1071(copyto)
#    681666    0.095    0.000    0.095    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\multiarray.py:80(empty_like)
#     35034    0.068    0.000    0.094    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\shape_base.py:81(atleast_2d)
#     23574    0.079    0.000    0.093    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\sparse\linalg\_interface.py:142(__new__)
#     48004    0.054    0.000    0.090    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_constraints.py:420(<listcomp>)
#     24002    0.080    0.000    0.090    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_minimize.py:973(standardize_constraints)
#     49486    0.053    0.000    0.088    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\function_base.py:346(iterable)
#      5516    0.008    0.000    0.073    0.000 <__array_function__ internals>:177(append)
#     24002    0.070    0.000    0.070    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\_methods.py:106(_clip_dep_invoke_with_casting)
#     17200    0.024    0.000    0.065    0.000 c:\Users\Ander\OneDrive - University of Copenhagen\Kandidat\1. semester\Introduction to Programming and Numerical Analysis\Python\Egen-mappe\modelproject\CES_function.py:86(utility_optimize)
#     23584    0.051    0.000    0.061    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\getlimits.py:457(__new__)
#     99004    0.042    0.000    0.060    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_constraints.py:12(_arr_to_scalar)
#      5516    0.016    0.000    0.058    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\function_base.py:5337(append)
#     24013    0.029    0.000    0.056    0.000 {built-in method builtins.all}
#     48004    0.028    0.000    0.050    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_constraints.py:422(<listcomp>)
#     48004    0.043    0.000    0.050    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\_methods.py:101(_clip_dep_is_byte_swapped)
# 49027/49005    0.049    0.000    0.049    0.000 {built-in method builtins.getattr}
#     24012    0.030    0.000    0.046    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:537(<listcomp>)
#     49354    0.026    0.000    0.045    0.000 {built-in method builtins.any}
#     23578    0.044    0.000    0.044    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.041    0.041 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\figure.py:632(add_subplot)
#         1    0.000    0.000    0.041    0.041 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:574(__init__)
#     17200    0.040    0.000    0.040    0.000 c:\Users\Ander\OneDrive - University of Copenhagen\Kandidat\1. semester\Introduction to Programming and Numerical Analysis\Python\Egen-mappe\modelproject\CES_function.py:74(utility)
#     49489    0.036    0.000    0.036    0.000 {built-in method builtins.iter}
#     24002    0.035    0.000    0.035    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_constraints.py:402(<listcomp>)
#         1    0.000    0.000    0.029    0.029 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:1388(clear)
#         1    0.000    0.000    0.029    0.029 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:1262(__clear)
#    117870    0.029    0.000    0.029    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\einsumfunc.py:989(_einsum_dispatcher)
#     96038    0.028    0.000    0.028    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:541(<genexpr>)
#     24002    0.027    0.000    0.027    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_optimize.py:172(__getattr__)
#     47148    0.025    0.000    0.025    0.000 {method 'strip' of 'bytes' objects}
#     73/48    0.000    0.000    0.025    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:443(wrapper)
#     11032    0.007    0.000    0.023    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\shape_base.py:218(_vhstack_dispatcher)
#    192832    0.023    0.000    0.023    0.000 {built-in method builtins.callable}
#     23574    0.022    0.000    0.022    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_lbfgsb_py.py:286(<listcomp>)
#     24002    0.016    0.000    0.020    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\sparse\_base.py:1301(isspmatrix)
#    142308    0.020    0.000    0.020    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3160(_ndim_dispatcher)
#     49288    0.018    0.000    0.018    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:25(_maybe_view_as_subclass)
#     98576    0.018    0.000    0.018    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:344(<genexpr>)
#     23574    0.018    0.000    0.018    0.000 {method 'decode' of 'bytes' objects}
#       428    0.001    0.000    0.017    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:545(<listcomp>)
#     11044    0.007    0.000    0.016    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\shape_base.py:207(_arrays_for_stack_dispatcher)
#     50476    0.016    0.000    0.016    0.000 {method 'get' of 'dict' objects}
#       6/4    0.000    0.000    0.014    0.003 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:583(__get__)
#         6    0.000    0.000    0.014    0.002 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:1544(_get_tick)
#     23738    0.014    0.000    0.014    0.000 {built-in method __new__ of type object at 0x00007FFC8111AD50}
#        12    0.000    0.000    0.014    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:855(clear)
#     24002    0.012    0.000    0.012    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_optimize.py:216(_check_unknown_options)
#     49288    0.012    0.000    0.012    0.000 {method '__exit__' of 'numpy.nditer' objects}
#     47168    0.011    0.000    0.011    0.000 {built-in method _operator.index}
#         8    0.000    0.000    0.011    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:918(set_tick_params)
#         6    0.000    0.000    0.011    0.002 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:58(__init__)
#     24452    0.011    0.000    0.011    0.000 {method 'lower' of 'str' objects}
#         2    0.000    0.000    0.010    0.005 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3155(grid)
#         4    0.000    0.000    0.010    0.002 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:1621(grid)
#     48004    0.009    0.000    0.009    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:362(_broadcast_to_dispatcher)
#     34456    0.009    0.000    0.009    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\multiarray.py:148(concatenate)
#     11230    0.009    0.000    0.009    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.009    0.004 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:1082(set_clip_path)
#         1    0.000    0.000    0.008    0.008 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:818(_init_axis)
#         3    0.000    0.000    0.008    0.003 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:416(__init__)
#       202    0.002    0.000    0.008    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:1180(_update_props)
#       129    0.000    0.000    0.007    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:147(<lambda>)
#       129    0.000    0.000    0.007    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:1227(set)
#       856    0.003    0.000    0.007    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py:32(seterr)
#       175    0.000    0.000    0.007    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:1216(_internal_update)
#        26    0.001    0.000    0.006    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\lines.py:272(__init__)
#         3    0.000    0.000    0.006    0.002 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:477(__init__)
#       428    0.001    0.000    0.006    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py:429(__enter__)
#        14    0.000    0.000    0.006    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:765(_set_scale)
#        14    0.000    0.000    0.006    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\scale.py:103(set_default_locators_and_formatters)
#        48    0.001    0.000    0.006    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\text.py:185(_reset_visual_defaults)
#     24002    0.006    0.000    0.006    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_optimize.py:324(hess)
#         1    0.000    0.000    0.006    0.006 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\pyplot.py:691(figure)
#         1    0.000    0.000    0.005    0.005 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\pyplot.py:381(new_figure_manager)
#         1    0.000    0.000    0.005    0.005 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py:21(new_figure_manager)
#     24012    0.005    0.000    0.005    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py:475(_broadcast_arrays_dispatcher)
#        24    0.000    0.000    0.005    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\text.py:132(__init__)
#         1    0.000    0.000    0.005    0.005 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:197(legend)
#         1    0.000    0.000    0.005    0.005 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend.py:345(__init__)
#         4    0.000    0.000    0.005    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\spines.py:208(register_axis)
#     35034    0.004    0.000    0.004    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\shape_base.py:77(_atleast_2d_dispatcher)
#         4    0.000    0.000    0.004    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1443(plot)
#     24002    0.004    0.000    0.004    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2079(_clip_dispatcher)
#         1    0.000    0.000    0.004    0.004 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend.py:808(_init_legend_box)
#        15    0.000    0.000    0.004    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:221(connect)
#         4    0.000    0.000    0.004    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\spines.py:221(clear)
#       428    0.001    0.000    0.004    0.000 <__array_function__ internals>:177(asfarray)
#        22    0.000    0.000    0.004    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:778(set_clip_path)
#         1    0.000    0.000    0.004    0.004 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py:30(new_figure_manager_given_figure)
#        15    0.000    0.000    0.004    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:119(_weak_or_strong_ref)
#         1    0.000    0.000    0.004    0.004 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\backend_bases.py:3576(new_figure_manager_given_figure)
#         1    0.000    0.000    0.004    0.004 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1731(new_manager)
#         1    0.000    0.000    0.004    0.004 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2850(create_with_canvas)
#         1    0.000    0.000    0.004    0.004 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2813(__init__)
#        15    0.000    0.000    0.003    0.000 c:\Users\Ander\anaconda3\lib\weakref.py:47(__new__)
#         3    0.000    0.000    0.003    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2415(mpl_connect)
#        17    0.003    0.000    0.003    0.000 {method 'format' of 'str' objects}
#       430    0.001    0.000    0.003    0.000 {method 'max' of 'numpy.ndarray' objects}
#         7    0.000    0.000    0.003    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:2496(_init)
#         2    0.000    0.000    0.003    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:643(__init__)
#        14    0.000    0.000    0.003    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\ticker.py:427(__init__)
#       430    0.000    0.000    0.003    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\_methods.py:38(_amax)
#        18    0.000    0.000    0.003    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\patches.py:262(get_transform)
#       428    0.001    0.000    0.003    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\type_check.py:84(asfarray)
# 2101/1839    0.002    0.000    0.003    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:319(stale)
#         4    0.000    0.000    0.003    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2295(add_line)
#        49    0.000    0.000    0.003    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\text.py:1307(set_fontproperties)
#      1646    0.001    0.000    0.003    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\__init__.py:742(__getitem__)
#       160    0.001    0.000    0.003    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1726(normalize_kwargs)
#       856    0.002    0.000    0.003    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py:131(geterr)
#        14    0.000    0.000    0.003    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\ticker.py:533(set_useMathText)
#        18    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\patches.py:742(get_patch_transform)
#       428    0.001    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py:434(__exit__)
#       428    0.001    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\scipy\optimize\_slsqp_py.py:354(<listcomp>)
#         6    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:237(set_clip_path)
#        42    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\markers.py:228(__init__)
#        14    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:351(_apply_params)
#        10    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\lines.py:1026(get_path)
#        10    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\lines.py:654(recache)
#       431    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:417(pchanged)
#         4    0.000    0.000    0.002    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend_handler.py:104(legend_artist)
#       6/4    0.000    0.000    0.002    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:1162(_set_lim)
#         4    0.000    0.000    0.002    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend_handler.py:286(create_artists)
#         1    0.000    0.000    0.002    0.002 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:2492(__init__)
#        14    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\ticker.py:2889(__init__)
#        58    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\font_manager.py:588(__init__)
#         1    0.000    0.000    0.002    0.002 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:2233(__init__)
#        27    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\text.py:221(update)
#        14    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\ticker.py:1969(__init__)
#        84    0.001    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:180(__init__)
#        42    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\markers.py:327(_set_marker)
#         7    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:2237(_init)
#         4    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2323(_update_line_limits)
#        14    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\ticker.py:2031(set_params)
#         1    0.000    0.000    0.002    0.002 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\figure.py:2373(__init__)
#       438    0.001    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:291(process)
#       438    0.000    0.000    0.002    0.000 {built-in method builtins.next}
#         7    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\patches.py:48(__init__)
#         8    0.000    0.000    0.002    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:241(__call__)
#        74    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\text.py:985(set_color)
#        50    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\font_manager.py:608(_from_any)
#         4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:406(_plot_args)
#       100    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\colors.py:237(_check_color_like)
#       436    0.001    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\numerictypes.py:356(issubdtype)
#       2/1    0.000    0.000    0.001    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3573(set_xlim)
#      1646    0.001    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\__init__.py:691(_get)
#       969    0.001    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:101(check_in_list)
#         1    0.000    0.000    0.001    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:1206(_gen_axes_spines)
#         1    0.000    0.000    0.001    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:1221(<dictcomp>)
#         4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\spines.py:425(linear_spine)
#       100    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\colors.py:218(is_color_like)
#       243    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\colors.py:213(_is_nth_color)
#        14    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\ticker.py:2010(_validate_steps)
#         2    0.000    0.000    0.001    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3314(tick_params)
#        12    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#        12    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(column_stack)
#       143    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\colors.py:265(to_rgba)
#       158    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\copy.py:66(copy)
#         4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:544(<listcomp>)
#         8    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:537(<genexpr>)
#         4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\spines.py:35(__init__)
#         4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:347(_makeline)
#        24    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\ipykernel\iostream.py:518(write)
#        12    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\shape_base.py:612(column_stack)
#       856    0.001    0.000    0.001    0.000 {built-in method numpy.seterrobj}
#      5516    0.001    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\function_base.py:5333(_append_dispatcher)
#        27    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:1205(update)
#       404    0.001    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1994(_setattr_cm)
#       6/4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:2208(setter)
#       202    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\contextlib.py:130(__enter__)
#        51    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\font_manager.py:893(copy)
#         2    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\patches.py:689(__init__)
#        92    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:438(set_transform)
#       243    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\re.py:187(match)
#        14    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:550(_get_data_path)
#        87    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:737(set_figure)
#         4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend_handler.py:87(update_prop)
#       159    0.001    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:194(set_children)
#        14    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:1663(update_units)
#        24    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\ipykernel\iostream.py:448(_schedule_flush)
#     28/14    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\units.py:164(get_converter)
#        69    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:1335(__add__)
#         5    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\offsetbox.py:718(__init__)
#        14    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\pathlib.py:957(__new__)
#        12    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\ipykernel\iostream.py:202(schedule)
#      10/4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:855(viewLim)
#      10/4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:841(_unstale_viewLim)
#        31    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:2323(blended_transform_factory)
#        14    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\pathlib.py:589(_from_parts)
#        69    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:2503(composite_transform_factory)
#        10    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2510(_process_unit_info)
#       858    0.001    0.000    0.001    0.000 {built-in method builtins.sum}
#        14    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\font_manager.py:1200(findfont)
#         4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend_handler.py:78(_update_prop)
#         4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend_handler.py:84(_default_update_prop)
#         4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\lines.py:1335(update_from)
#        14    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\pathlib.py:569(_parse_args)
#        18    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\patches.py:876(get_bbox)
#         1    0.000    0.000    0.001    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2809(autoscale_view)
#      1712    0.001    0.000    0.001    0.000 {built-in method numpy.geterrobj}
#       202    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\contextlib.py:279(helper)
#        42    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:754(__init__)
#        29    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:2281(__init__)
#         8    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(linspace)
#       202    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\contextlib.py:139(__exit__)
#       872    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\numerictypes.py:282(issubclass_)
#       428    0.001    0.000    0.001    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#        12    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\lines.py:1182(set_marker)
#        80    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\markers.py:277(_recache)
#         8    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\function_base.py:23(linspace)
#        20    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:809(from_extents)
#       160    0.001    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1765(<dictcomp>)
#     236/4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\copy.py:128(deepcopy)
#       204    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:103(_stale_axes_callback)
#       100    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\font_manager.py:807(set_size)
#        72    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\copy.py:259(_reconstruct)
#      16/4    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\copy.py:227(_deepcopy_dict)
#        44    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\lines.py:635(set_data)
#        28    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1675(_safe_first_finite)
#        12    0.001    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\zmq\sugar\socket.py:613(send)
#        14    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\pathlib.py:56(parse_parts)
#        41    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\text.py:1098(set_fontsize)
#       135    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:65(check_isinstance)
#        74    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:1048(set_visible)
#        20    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\patches.py:343(_set_facecolor)
#        60    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:2347(__init__)
#        28    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:1832(_set_formatter)
#         2    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2868(handle_single_axis)
#         1    0.000    0.000    0.001    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:1189(_gen_axes_patch)
#       203    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:1764(__init__)
#       116    0.000    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:157(invalidate)
#         1    0.000    0.000    0.001    0.001 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:790(set_subplotspec)
#       428    0.001    0.000    0.001    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py:425(__init__)
#       202    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\contextlib.py:102(__init__)
#      1646    0.000    0.000    0.000    0.000 {function RcParams.__getitem__ at 0x000001C87DB75360}
#        11    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:235(_connect_picklable)
#        16    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\offsetbox.py:217(__init__)
#        28    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1715(<genexpr>)
#        20    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:790(unit)
#        48    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\text.py:1030(set_linespacing)
#      2101    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:851(get_animated)
#      16/1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\offsetbox.py:227(set_figure)
#        26    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\lines.py:1052(set_color)
#        14    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1685(safe_isfinite)
# ...
#        12    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\markers.py:299(get_fillstyle)
#        14    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\__init__.py:318(wrapper)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\_collections_abc.py:865(__len__)
#        12    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\threading.py:553(is_set)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\spines.py:541(from_dict)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:338(_setdefaults)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2446(_unit_change_handler)
#        11    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        14    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\function_base.py:1291(_diff_dispatcher)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\projections\__init__.py:98(get_projection_class)
#         8    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:874(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3403(set_axis_on)
#         8    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:761(get_scale)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:112(__eq__)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2892(<genexpr>)
#        14    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:389(<dictcomp>)
#        10    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2567(<listcomp>)
#         8    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:1753(<lambda>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\figure.py:82(__init__)
#        10    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1623(<lambda>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py:33(get_fig_manager)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\figure.py:2890(set_canvas)
#        14    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:394(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\gridspec.py:430(<dictcomp>)
#        14    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:376(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:543(__init__)
#         6    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:1180(<listcomp>)
#        14    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\logging\__init__.py:219(_acquireLock)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\gridspec.py:550(__init__)
#        16    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\path.py:211(vertices)
#         6    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:1718(have_units)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:2405(<lambda>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2039(__init__)
#         8    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:328(<genexpr>)
#        24    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\spines.py:584(__iter__)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\figure.py:86(as_list)
#         8    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:549(locator)
#        13    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:1093(get_label)
#         3    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1697(<lambda>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\figure.py:100(add)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend_handler.py:95(adjust_drawing_area)
#         3    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\_collections_abc.py:862(__init__)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1845(_str_lower_equal)
#         8    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\function_base.py:18(_linspace_dispatcher)
#        24    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:1362(depth)
#         8    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\enum.py:786(__reduce_ex__)
#         3    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:352(intervaly)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\widgets.py:38(__init__)
#         5    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend.py:1212(<genexpr>)
#         8    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend_handler.py:188(get_numpoints)
#         6    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:154(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'indices' of 'slice' objects}
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2844(notify_axes_change)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\gridspec.py:123(set_height_ratios)
#         2    0.000    0.000    0.000    0.000 {method 'sort' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\__init__.py:1286(is_interactive)
#        12    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:464(<genexpr>)
#         3    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\pyplot.py:198(_get_backend_mod)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:828(_set_autoscale_on)
#         8    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\multiarray.py:664(result_type)
#         6    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:1751(<lambda>)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\spines.py:587(__len__)
#        11    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:430(is_transform_set)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1646(<lambda>)
#         8    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:1028(minposy)
#         7    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:1375(get_mouseover)
#         8    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\path.py:225(codes)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:1652(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\spines.py:538(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:367(height)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\patches.py:2215(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\projections\__init__.py:73(get_projection_class)
#         3    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\gridspec.py:75(get_geometry)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\logging\__init__.py:228(_releaseLock)
#         8    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\scale.py:78(limit_range_for_scale)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\path.py:256(should_simplify)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\patches.py:2214(<listcomp>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\figure.py:94(bubble)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\figure.py:2733(_get_dpi)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:652(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:826(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axis.py:824(_get_autoscale_on)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\gridspec.py:101(set_width_ratios)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:643(set_snap)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3985(set_navigate_mode)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend.py:761(get_default_handler_map)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:134(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:141(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\patches.py:2454(__init__)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\gridspec.py:612(num2)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend.py:776(get_legend_handler_map)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:1080(set_in_layout)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:852(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend.py:1052(set_bbox_to_anchor)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:109(__call__)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:898(get_clip_path)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3969(set_navigate)
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         4    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\numeric.py:353(_full_like_dispatcher)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\shape_base.py:1243(<genexpr>)
#         4    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\path.py:244(simplify_threshold)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2599(use_sticky_edges)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\gridspec.py:191(<listcomp>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\gridspec.py:608(num2)
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2491(_cumsum_dispatcher)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\artist.py:847(get_visible)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\legend.py:1166(set_draggable)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\multiarray.py:1021(unravel_index)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:848(_sort_dispatcher)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:1006(minpos)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\transforms.py:2154(inverted)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2941(set_window_title)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\gridspec.py:199(<listcomp>)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\matplotlib\gridspec.py:616(get_gridspec)
#         1    0.000    0.000    0.000    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\shape_base.py:735(_array_split_dispatcher)
#         2    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:546(_swapaxes_dispatcher)
#         1    0.000    0.000    0.000    0.000 c:\Users\Ander\anaconda3\lib\site-packages\numpy\lib\shape_base.py:1167(_tile_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
